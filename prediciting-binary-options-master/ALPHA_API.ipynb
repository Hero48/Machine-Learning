# %%
import requests
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=EURUSD&interval=15min&apikey=5X2V9HPVK26OQKMT'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'Meta Data': {'1. Information': 'Intraday (15min) open, high, low, close prices and volume', '2. Symbol': 'EURUSD', '3. Last Refreshed': '2023-05-12 17:15:00', '4. Interval': '15min', '5. Output Size': 'Compact', '6. Time Zone': 'US/Eastern'}, 'Time Series (15min)': {'2023-05-12 17:15:00': {'1. open': '1.0849', '2. high': '1.0849', '3. low': '1.0847', '4. close': '1.0847', '5. volume': '0'}, '2023-05-12 17:00:00': {'1. open': '1.0849', '2. high': '1.0850', '3. low': '1.0847', '4. close': '1.0848', '5. volume': '0'}, '2023-05-12 16:45:00': {'1. open': '1.0850', '2. high': '1.0851', '3. low': '1.0848', '4. close': '1.0849', '5. volume': '0'}, '2023-05-12 16:30:00': {'1. open': '1.0850', '2. high': '1.0851', '3. low': '1.0847', '4. close': '1.0850', '5. volume': '0'}, '2023-05-12 16:15:00': {'1. open': '1.0850', '2. high': '1.0852', '3. low': '1.0848', '4. close': '1.0850', '5. volume': '0'}, '2023-05-12 16:00:00': {'1. open': '1.0853', '2. high': '1.0853', '3. low': '1.0849', '4. clos
# ...
